# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pylab as pl

# %%
file_path = 'Resources/clean_data_untouched.csv'
clean_data = pd.read_csv(file_path)
clean_data.head()
# Out:
#    Unnamed: 0  Report_No Reported_Date Reported_Time   From_Date From_Time  \
# 0           0  180067842    09/02/2018         18:15  09/02/2018     18:15
# 1           1  180007664    01/31/2018         17:22  01/31/2018     13:30
# 2           2  180007431    01/30/2018         19:00  05/14/2017     12:00
# 3           3  180007426    01/30/2018         17:41  01/29/2018     00:01
# 4           4  180094471    12/08/2018         13:00  12/08/2018     13:00
#
#       To_Date To_Time  Offense IBRS  ... Rep_Dist Area DVFlag Invl_No  \
# 0         NaN     NaN      501  220  ...   PJ2783  EPD      U       1
# 1  01/31/2018   15:45     1001  250  ...   PJ3255  CPD      U       2
# 2  01/30/2018   19:00     1750  11D  ...   PJ3505  EPD      Y       1
# 3  01/30/2018   17:41      501  220  ...   PJ5421  MPD      U       1
# 4         NaN     NaN     1401  290  ...   PJ3350  EPD      U       1
#
#    Involvement Race Sex   Age  Firearm Used Flag  \
# ...

# %%
file_path2 = 'Resources/Crime_Category.csv'
crime_category = pd.read_csv(file_path2)
crime_category.head()
# Out:
#   IBRS  Offense Category
# 0  200             Arson
# 1  13A  Assault Offenses
# 2  13B  Assault Offenses
# 3  13C  Assault Offenses
# 4  510           Bribery

# %%
new_data1 = clean_data.filter(['Description','Offense','IBRS'], axis = 1)
new_data1.head()
data1 = new_data1.groupby(['Offense','IBRS','Description']).count()
data1
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
new_data = clean_data.filter(['IBRS','Area','Invl_No'], axis = 1)
new_data.head()
# Out:
#   IBRS Area  Invl_No
# 0  220  EPD        1
# 1  250  CPD        2
# 2  11D  EPD        1
# 3  220  MPD        1
# 4  290  EPD        1

# %%
data_for_count = pd.merge(new_data,crime_category,on ='IBRS')
data_for_count = data_for_count.filter(['Offense Category','Area','Invl_No'],axis=1)
data_for_count.head()
# Out:
#                   Offense Category Area  Invl_No
# 0  Burglary/ Breaking and Entering  EPD        1
# 1  Burglary/ Breaking and Entering  MPD        1
# 2  Burglary/ Breaking and Entering  EPD        1
# 3  Burglary/ Breaking and Entering  SCP        1
# 4  Burglary/ Breaking and Entering  MPD        1

# %%
data_for_heatmap = data_for_count.groupby(['Offense Category','Area']).count()
data_for_heatmap = data_for_heatmap.reset_index()
data_for_heatmap.head()
# Out:
#   Offense Category  Area  Invl_No
# 0            Arson   CPD       65
# 1            Arson   EPD      262
# 2            Arson   MPD      100
# 3            Arson   NPD        6
# 4            Arson  OSPD        2

# %%
heatmap_data = pd.pivot_table(data_for_heatmap,values='Invl_No',index = ['Offense Category'], columns = 'Area')
plt.figure(figsize=(30,40))
heatmap = sns.heatmap(heatmap_data, cmap="Blues")
fig = heatmap.get_figure()
fig.savefig('Images/vamsi_figure1.png')

# %%
new_data = clean_data.filter(['Description','Area','Firearm Used Flag'], axis = 1)
new_data.head()
# Out:
#             Description Area Firearm Used Flag
# 0  Burglary - Residence  EPD                 N
# 1               Forgery  CPD                 N
# 2  Sex Off Fondle - mol  EPD                 N
# 3  Burglary - Residence  MPD                 N
# 4       Property Damage  EPD                 N
